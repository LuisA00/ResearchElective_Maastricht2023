# %%
import datalad.api as dl

# %%
# !datalad install -g https://github.com/OpenNeuroDerivatives/ds003782-mriqc.git
# Out:
# Total:   0%|                                   | 0.00/7.00G [00:00<?, ? Bytes/s]
# Get .reproma .. 721/stdout.0:   0%|             | 0.00/269k [00:00<?, ? Bytes/s]
# Get .reproma .. 721/stdout.0:  13%|▋    | 35.3k/269k [00:00<00:00, 317k Bytes/s]
# Get .reproma .. 721/stdout.0:  30%|█▍   | 80.4k/269k [00:00<00:00, 364k Bytes/s]
# Get .reproma .. 721/stdout.0:  68%|████  | 184k/269k [00:00<00:00, 585k Bytes/s]
# Total:   0%|                         | 269k/7.00G [00:01<12:06:32, 161k Bytes/s]
# Get .reproma .. 721/stdout.1:   0%|             | 0.00/261k [00:00<?, ? Bytes/s]
#
# Get .reproma .. 21/stdout.10:   0%|             | 0.00/269k [00:00<?, ? Bytes/s]
# Total:   0%|                          | 798k/7.00G [00:02<5:37:48, 345k Bytes/s]
# Get .reproma .. 21/stdout.11:   0%|             | 0.00/269k [00:00<?, ? Bytes/s]
#
# Get .reproma .. 21/stdout.12:   0%|             | 0.00/269k [00:00<?, ? Bytes/s]
# Total:   0%|                         | 1.34M/7.00G [00:02<4:10:49, 465k Bytes/s]
# ...

# %%
# !datalad status --annex
# Out:
# untracked: .DS_Store (file)
# untracked: Downloading_derv.ipynb (file)
# untracked: ds003782-mriqc (directory)
#  modified: Validating_Yeo17_Fit.ipynb (file)

# %%
# !datalad get ds003782-mriqc/sub-19_task-probabilitymixedgambles_run-01_bold.html

# %%
# !datalad get . -r
# Out:
# [INFO   ] Ensuring presence of Dataset(/Users/luisalvarez/Documents/GitHub/ResearchElective_Maastricht2023) to get /Users/luisalvarez/Documents/GitHub/ResearchElective_Maastricht2023

# %%
fmriprep-docker Neural_Correlates_of_EffortBased_Valuation_Under_Risk Prepro_data --participant_label sub-19 --task probabilitymixedgambles --fs-license-file /Users/luisalvarez/Documents/Datasets/license.txt
--ignore slicetiming
fmriprep Neural_Correlates_of_EffortBased_Valuation_Under_Risk Prepro_data --participant_label sub-19 --task probabilitymixedgambles --ignore slicetiming
fmriprep-docker ds003782-mriqc Prepro_data --participant_label sub-19 --task probabilitymixedgambles
ds003782-mriqc
